# %%
import torch
print("Using torch", torch.__version__)
# Out:
# Using torch 1.10.0+cu111

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
#Python 3.7 required
# !python -V
# Out:
# Python 3.7.12

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/stylegan2-ada-requirements.txt ./requirements.txt

# %%
# !pip install -r ./requirements.txt -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 195 kB 8.1 MB/s
# ...
#      |████████████████████████████████| 108 kB 84.2 MB/s
# ...
#      |████████████████████████████████| 26.9 MB 1.2 MB/s
# ...
#      |███████████████████████         | 834.1 MB 70.5 MB/s eta 0:00:05tcmalloc: large alloc 1147494400 bytes == 0x55e8b9e8c000 @  0x7f6641a40615 0x55e8b76e83bc 0x55e8b77c918a 0x55e8b76eb1cd 0x55e8b77ddb3d 0x55e8b775f458 0x55e8b775a02f 0x55e8b76ecaba 0x55e8b775f2c0 0x55e8b775a02f 0x55e8b76ecaba 0x55e8b775bcd4 0x55e8b77de986 0x55e8b775b350 0x55e8b77de986 0x55e8b775b350 0x55e8b77de986 0x55e8b775b350 0x55e8b76ecf19 0x55e8b7730a79 0x55e8b76ebb32 0x55e8b775f1dd 0x55e8b775a02f 0x55e8b76ecaba 0x55e8b775bcd4 0x55e8b775a02f 0x55e8b76ecaba 0x55e8b775aeae 0x55e8b76ec9da 0x55e8b775b108 0x55e8b775a02f
# ...

# %%
#download dataset
# !cp /content/drive/MyDrive/cp-vton-squared.zip ./ 

#download previus snapshot
# !cp /content/drive/MyDrive/network-snapshot-000120.pkl ./network-snapshot.pkl

# %%
# !unzip cp-vton-squared.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cp-vton-squared/004249_1.jpg
#   inflating: cp-vton-squared/011139_1.jpg
#   inflating: cp-vton-squared/010709_1.jpg
#   inflating: cp-vton-squared/005479_1.jpg
#   inflating: cp-vton-squared/008974_1.jpg
#   inflating: cp-vton-squared/008931_1.jpg
#   inflating: cp-vton-squared/018464_1.jpg
#   inflating: cp-vton-squared/009974_1.jpg
#   inflating: cp-vton-squared/009137_1.jpg
#   inflating: cp-vton-squared/019421_1.jpg
#   inflating: cp-vton-squared/011709_1.jpg
#   inflating: cp-vton-squared/004479_1.jpg
#   inflating: cp-vton-squared/003169_1.jpg
#   inflating: cp-vton-squared/016219_1.jpg
#   inflating: cp-vton-squared/009931_1.jpg
#   inflating: cp-vton-squared/009172_1.jpg
#   inflating: cp-vton-squared/019464_1.jpg
#   inflating: cp-vton-squared/014969_1.jpg
#   inflating: cp-vton-squared/006824_1.jpg
#   inflating: cp-vton-squared/001577_1.jpg
#   inflating: cp-vton-squared/004311_1.jpg
# ...

# %%
# !git clone https://github.com/abeysinghehd/stylegan2-ada-pytorch.git
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 140, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 140 (delta 6), reused 0 (delta 0), pack-reused 128
# Receiving objects: 100% (140/140), 1.13 MiB | 15.42 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
# !python stylegan2-ada-pytorch/dataset_tool.py --source ./cp-vton-squared --dest ./datasets/cloth-256.zip --width=256 --height=256
# Out:
# 100% 14221/14221 [00:54<00:00, 258.92it/s]

# %%
# !python stylegan2-ada-pytorch/train.py --outdir=./training-runs-256 --data=./datasets/cloth-256.zip --gpus=1 --augpipe=bgcfnc --snap=10 --resume=./network-snapshot.pkl
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "./datasets/cloth-256.zip",
#     "use_labels": false,
#     "max_size": 14221,
#     "xflip": false,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 16384,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
# ...
